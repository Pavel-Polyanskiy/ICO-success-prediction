# %%
# !pip install textstat
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.1/105.1 KB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 29.9 MB/s eta 0:00:00
# ...

# %%
import textstat
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Research papers/Thesis /Data/processed data/wp_text_cleaned_v2.csv")

# %%
df['readability_index'] = df['text'].apply(lambda text: textstat.flesch_reading_ease(str(text)))

# %%
df = df[['name', "readability_index"]]

# %%
df.to_csv("/content/drive/MyDrive/Research papers/Thesis /Data/processed data/readability_index.csv", index = None)
